# %% [markdown]
# In this notebook, we plot several common functions in 3D which would be used for testing optimization algorithms later.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
from matplotlib import cm
from matplotlib.colors import LogNorm

def plot_function_3d(f):
    minima = np.array([0, 0])
    start_point = np.array([8, 8])
    #minima_ = minima.reshape(-1, 1)

    xmin, xmax = -10, 10
    ymin, ymax = -10, 10

    fig = plt.figure()
    ax = fig.gca(projection='3d', elev=50, azim=0)
#ax.plot([minima[0]], [minima[1]], 'r*', markersize=10)

# Make data.
    X = np.arange(xmin, xmax, 0.25)
    Y = np.arange(ymin, ymax, 0.25)
    X, Y = np.meshgrid(X, Y)
    Z = f(X, Y)

# Plot the surface.
    surf = ax.plot_surface(X, Y, Z, cmap=cm.viridis,
                       linewidth=0, antialiased=True, norm=LogNorm())
    ax.view_init(50, 50)
    plt.show()

# %% [markdown]
# ### Bowl functions
# #### Bohachevsky function and Trid functions

# %%
def bohachevsky(x, y):
    return x**2 + 2*y**2 - 0.3*np.cos(3*3.14*x) -     0.4*np.cos(4*3.14*y) + 0.7
def trid(x, y):
    return (x-1)**2 + (y-1)**2 - x*y

# %% [markdown]
# ### Plate functions
# #### Booth, Matyas and Zakharov functions

# %%
def booth(x, y):
    return (x + 2*y - 7)**2 + (2*x + y - 5)**2
def matyas(x, y):
    return 0.26*(x**2 + y**2) - 0.48*x*y
def zakharov(x, y):
    return (x**2 + y**2) + (0.5*x + y)**2 + (0.5*x + y)**4

# %% [markdown]
# ### Valley functions
# #### Rozenbrock, Beale and Six Hump Camel functions

# %%
def rozenbrock(x, y):
    return (1-x)**2 + 100*(y - x**2)**2
def beale(x, y):
    return (1.5 - x + x*y)**2 + (2.25 - x + x*y**2)**2 + (2.65 - x + x*y**3)**2
def six_hump(x, y):
    return (4 - 2.1*x**2 + x**4/3)*x**2 + x*y + (-4 + 4*y**2)*y**2

# %%
plot_function_3d(bohachevsky)

# %%
plot_function_3d(trid)

# %%
plot_function_3d(booth)

# %%
plot_function_3d(matyas)

# %%
plot_function_3d(zakharov)

# %%
plot_function_3d(rozenbrock)

# %%
plot_function_3d(beale)

# %%
plot_function_3d(six_hump)
